# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# # **Data Imported**

# %%
query = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$query=" +  requests.utils.quote("SELECT * WHERE complaint_type = 'Rodent' LIMIT 1000000")

# %%
rat_requests = pd.read_csv(query)

# %% [markdown]
# # **Data Descriptions**

# %%
rat_requests.head(3)
# Out:
#    unique_key             created_date closed_date agency  \
# 0    60888695  2024-04-17T00:58:41.000         NaN  DOHMH
# 1    60891441  2024-04-17T00:30:33.000         NaN  DOHMH
# 2    60892817  2024-04-17T00:01:11.000         NaN  DOHMH
#
#                                agency_name complaint_type    descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent  Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent  Rat Sighting
#
#              location_type  incident_zip      incident_address  ...  \
# 0  3+ Family Apt. Building       11206.0    201 PULASKI STREET  ...
# 1  3+ Family Apt. Building       10467.0  316 EAST  211 STREET  ...
# 2  3+ Family Apt. Building       10035.0  347 EAST  119 STREET  ...
#
#   vehicle_type taxi_company_borough taxi_pick_up_location bridge_highway_name  \
# 0          NaN                  NaN                   NaN                 NaN
# 1          NaN                  NaN                   NaN                 NaN
# 2          NaN                  NaN                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 0                      NaN       NaN                    NaN  40.693035
# 1                      NaN       NaN                    NaN  40.880094
# 2                      NaN       NaN                    NaN  40.798157
#
#    longitude                                         location
# 0 -73.943493  \n,  \n(40.693035485169446, -73.94349279614431)
# 1 -73.873414  \n,  \n(40.880093772136696, -73.87341414442069)
# 2 -73.934504   \n,  \n(40.79815738239905, -73.93450416049585)
#
# [3 rows x 41 columns]

# %%
rat_requests.tail(3)
# Out:
#         unique_key             created_date closed_date agency  \
# 431521    15633965  2010-01-01T12:11:44.000         NaN  DOHMH
# 431522    15633054  2010-01-01T11:20:45.000         NaN  DOHMH
# 431523    15633803  2010-01-01T08:29:58.000         NaN  DOHMH
#
#                                     agency_name complaint_type  \
# 431521  Department of Health and Mental Hygiene         Rodent
# 431522  Department of Health and Mental Hygiene         Rodent
# 431523  Department of Health and Mental Hygiene         Rodent
#
#                           descriptor            location_type  incident_zip  \
# 431521  Condition Attracting Rodents      1-2 Family Dwelling       11420.0
# 431522                  Rat Sighting      1-2 Family Dwelling       11365.0
# 431523                  Rat Sighting  3+ Family Apt. Building       11206.0
#
#           incident_address  ... vehicle_type taxi_company_borough  \
# 431521   119-27 130 STREET  ...          NaN                  NaN
# 431522    59-13 159 STREET  ...          NaN                  NaN
# 431523  202 PULASKI STREET  ...          NaN                  NaN
#
#        taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 431521                   NaN                 NaN                      NaN
# 431522                   NaN                 NaN                      NaN
# 431523                   NaN                 NaN                      NaN
#
#        road_ramp bridge_highway_segment   latitude  longitude  \
# 431521       NaN                    NaN  40.674091 -73.808377
# 431522       NaN                    NaN  40.739983 -73.809299
# 431523       NaN                    NaN  40.692989 -73.943771
#
#                                               location
# 431521  \n,  \n(40.67409083763361, -73.80837696748092)
# 431522  \n,  \n(40.73998332248969, -73.80929891501533)
# 431523  \n,  \n(40.69298896011082, -73.94377050323628)
#
# [3 rows x 41 columns]

# %%
rat_requests.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
rat_requests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431524 entries, 0 to 431523
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   unique_key                      431524 non-null  int64
#  1   created_date                    431524 non-null  object
#  2   closed_date                     400473 non-null  object
#  3   agency                          431524 non-null  object
#  4   agency_name                     431524 non-null  object
#  5   complaint_type                  431524 non-null  object
#  6   descriptor                      431524 non-null  object
#  7   location_type                   431506 non-null  object
#  8   incident_zip                    430874 non-null  float64
#  9   incident_address                415866 non-null  object
#  10  street_name                     415865 non-null  object
#  11  cross_street_1                  380910 non-null  object
#  12  cross_street_2                  380939 non-null  object
#  13  intersection_street_1           196768 non-null  object
#  14  intersection_street_2           196838 non-null  object
#  15  address_type                    430759 non-null  object
#  16  city                            426657 non-null  object
#  17  landmark                        166780 non-null  object
#  18  facility_type                   0 non-null       float64
#  19  status                          431524 non-null  object
#  20  due_date                        255961 non-null  object
#  21  resolution_description          406262 non-null  object
#  22  resolution_action_updated_date  417183 non-null  object
#  23  community_board                 431517 non-null  object
#  24  bbl                             361020 non-null  float64
#  25  borough                         431517 non-null  object
#  26  x_coordinate_state_plane        428507 non-null  float64
#  27  y_coordinate_state_plane        428511 non-null  float64
#  28  open_data_channel_type          431524 non-null  object
#  29  park_facility_name              431524 non-null  object
#  30  park_borough                    431517 non-null  object
#  31  vehicle_type                    0 non-null       float64
#  32  taxi_company_borough            0 non-null       float64
#  33  taxi_pick_up_location           0 non-null       float64
#  34  bridge_highway_name             0 non-null       float64
#  35  bridge_highway_direction        0 non-null       float64
#  36  road_ramp                       0 non-null       float64
#  37  bridge_highway_segment          0 non-null       float64
#  38  latitude                        428507 non-null  float64
#  39  longitude                       428507 non-null  float64
#  40  location                        428507 non-null  object
# dtypes: float64(14), int64(1), object(26)
# memory usage: 135.0+ MB

# %%
rat_requests.shape
# Out:
# (431524, 41)

# %% [markdown]
# # **Date Conversions**

# %%
rat_requests['created_date'] = pd.to_datetime(rat_requests['created_date'])

# %%
rat_requests['closed_date'] = pd.to_datetime(rat_requests['closed_date'])

# %%
rat_requests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431524 entries, 0 to 431523
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   unique_key                      431524 non-null  int64
#  1   created_date                    431524 non-null  datetime64[ns]
#  2   closed_date                     400473 non-null  datetime64[ns]
#  3   agency                          431524 non-null  object
#  4   agency_name                     431524 non-null  object
#  5   complaint_type                  431524 non-null  object
#  6   descriptor                      431524 non-null  object
#  7   location_type                   431506 non-null  object
#  8   incident_zip                    430874 non-null  float64
#  9   incident_address                415866 non-null  object
#  10  street_name                     415865 non-null  object
#  11  cross_street_1                  380910 non-null  object
#  12  cross_street_2                  380939 non-null  object
#  13  intersection_street_1           196768 non-null  object
#  14  intersection_street_2           196838 non-null  object
#  15  address_type                    430759 non-null  object
#  16  city                            426657 non-null  object
#  17  landmark                        166780 non-null  object
#  18  facility_type                   0 non-null       float64
#  19  status                          431524 non-null  object
#  20  due_date                        255961 non-null  object
#  21  resolution_description          406262 non-null  object
#  22  resolution_action_updated_date  417183 non-null  object
#  23  community_board                 431517 non-null  object
#  24  bbl                             361020 non-null  float64
#  25  borough                         431517 non-null  object
#  26  x_coordinate_state_plane        428507 non-null  float64
#  27  y_coordinate_state_plane        428511 non-null  float64
#  28  open_data_channel_type          431524 non-null  object
#  29  park_facility_name              431524 non-null  object
#  30  park_borough                    431517 non-null  object
#  31  vehicle_type                    0 non-null       float64
#  32  taxi_company_borough            0 non-null       float64
#  33  taxi_pick_up_location           0 non-null       float64
#  34  bridge_highway_name             0 non-null       float64
#  35  bridge_highway_direction        0 non-null       float64
#  36  road_ramp                       0 non-null       float64
#  37  bridge_highway_segment          0 non-null       float64
#  38  latitude                        428507 non-null  float64
#  39  longitude                       428507 non-null  float64
#  40  location                        428507 non-null  object
# dtypes: datetime64[ns](2), float64(14), int64(1), object(24)
# memory usage: 135.0+ MB

# %%
rat_requests['created_date'] = pd.to_datetime(rat_requests['created_date'])

# %%
rat_requests['created_year'] = rat_requests['created_date'].dt.year

# %%
rat_requests['created_year'].value_counts()
# Out:
# created_year
# 2023    41748
# 2022    41121
# 2021    38809
# 2017    35075
# 2018    32530
# 2019    31644
# 2016    31439
# 2015    29329
# 2020    27583
# 2014    24515
# 2013    22345
# 2010    22186
# 2011    21494
# 2012    21327
# 2024    10379
# Name: count, dtype: int64

# %%
rat_requests['created_month'] = rat_requests['created_date'].dt.month

# %%
rat_requests['created_month'].value_counts()
# Out:
# created_month
# 7     46128
# 8     45748
# 6     44048
# 5     41093
# 9     40321
# 10    37373
# 4     35860
# 3     33492
# 1     28324
# 11    27465
# 2     27388
# 12    24284
# Name: count, dtype: int64

# %%
rat_requests.head()
# Out:
#    unique_key        created_date closed_date agency  \
# 0    60888695 2024-04-17 00:58:41         NaT  DOHMH
# 1    60891441 2024-04-17 00:30:33         NaT  DOHMH
# 2    60892817 2024-04-17 00:01:11         NaT  DOHMH
# 3    60892810 2024-04-16 23:28:45         NaT  DOHMH
# 4    60887322 2024-04-16 23:20:23         NaT  DOHMH
#
#                                agency_name complaint_type  \
# 0  Department of Health and Mental Hygiene         Rodent
# 1  Department of Health and Mental Hygiene         Rodent
# 2  Department of Health and Mental Hygiene         Rodent
# 3  Department of Health and Mental Hygiene         Rodent
# 4  Department of Health and Mental Hygiene         Rodent
#
#                      descriptor            location_type  incident_zip  \
# 0                  Rat Sighting  3+ Family Apt. Building       11206.0
# 1                  Rat Sighting  3+ Family Apt. Building       10467.0
# 2                  Rat Sighting  3+ Family Apt. Building       10035.0
# 3  Condition Attracting Rodents  3+ Family Apt. Building       10037.0
# 4  Condition Attracting Rodents  3+ Family Apt. Building       11226.0
#
#        incident_address  ... taxi_pick_up_location bridge_highway_name  \
# 0    201 PULASKI STREET  ...                   NaN                 NaN
# 1  316 EAST  211 STREET  ...                   NaN                 NaN
# 2  347 EAST  119 STREET  ...                   NaN                 NaN
# 3    5 WEST  137 STREET  ...                   NaN                 NaN
# 4     1715 CATON AVENUE  ...                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 0                      NaN       NaN                    NaN  40.693035
# 1                      NaN       NaN                    NaN  40.880094
# 2                      NaN       NaN                    NaN  40.798157
# 3                      NaN       NaN                    NaN  40.814287
# 4                      NaN       NaN                    NaN  40.651126
#
#    longitude                                         location  created_year  \
# 0 -73.943493  \n,  \n(40.693035485169446, -73.94349279614431)          2024
# 1 -73.873414  \n,  \n(40.880093772136696, -73.87341414442069)          2024
# 2 -73.934504   \n,  \n(40.79815738239905, -73.93450416049585)          2024
# 3 -73.937245   \n,  \n(40.81428691061831, -73.93724473600929)          2024
# 4 -73.964074    \n,  \n(40.65112553104932, -73.9640736166386)          2024
#
#   created_month
# 0             4
# 1             4
# 2             4
# 3             4
# 4             4
#
# [5 rows x 43 columns]

# %%
rat_requests['count_row'] = 1

# %%
rat_requests.groupby(['borough', 'is_residential'])['count_row'].sum().reset_index()
# Out:
#           borough   is_residential  count_row
# 0           BRONX   is residential      66187
# 1           BRONX  not residential      15745
# 2        BROOKLYN   is residential     108442
# 3        BROOKLYN  not residential      42111
# 4       MANHATTAN   is residential      71357
# 5       MANHATTAN  not residential      33042
# 6          QUEENS   is residential      53571
# 7          QUEENS  not residential      20666
# 8   STATEN ISLAND   is residential      14386
# 9   STATEN ISLAND  not residential       5983
# 10    Unspecified   is residential         14
# 11    Unspecified  not residential         13

# %%
rat_requests['location_type'].value_counts()
# Out:
# location_type
# 3+ Family Apt. Building           184651
# 1-2 Family Dwelling                92217
# Other (Explain Below)              54137
# 3+ Family Mixed Use Building       27080
# Commercial Building                24444
# Vacant Lot                         12779
# Construction Site                   7585
# 1-2 Family Mixed Use Building       7358
# Vacant Building                     6473
# Parking Lot/Garage                  4058
# Catch Basin/Sewer                   2856
# Public Garden                       1323
# 3+ Family Apartment Building        1104
# Government Building                  895
# Single Room Occupancy (SRO)          888
# School/Pre-School                    707
# Street Area                          537
# Office Building                      437
# Day Care/Nursery                     424
# Residential Building                 365
# Hospital                             298
# Public Stairs                        282
# Apartment                            139
# Other                                115
# Residence                            110
# 1-3 Family Dwelling                   28
# Building (Non-Residential)            27
# Abandoned Building                    22
# Store                                 22
# Summer Camp                           21
# Restaurant                            20
# Residential Property                  18
# Restaurant/Bar/Deli/Bakery            16
# 3+ Family Apt.                        15
# Ground                                 8
# 1-3 Family Mixed Use Building          6
# School                                 6
# Grocery Store                          4
# Vacant Lot/Property                    4
# 3+Family Apt.                          3
# Retail Store                           3
# Private House                          3
# Commercial Property                    3
# Public/Unfenced Area                   2
# Cafeteria - Public School              2
# Beach                                  2
# Street Fair Vendor                     2
# Private Residence                      1
# Street Vendor                          1
# 1-2 FamilyDwelling                     1
# Cafeteria - College/University         1
# 3+ Family Apt                          1
# 3+ Family                              1
# Catering Service                       1
# Name: count, dtype: int64

# %%
residential_list = ['3+ Family Apt. Building', '1-2 Family Dwelling' , '3+ Family Mixed Use Building', '1-2 Family Mixed Use Building', '3+ Family Apartment Building', 'Single Room Occupancy (SRO)', 'Residential Building', 'Apartment', 'Residence', '1-3 Family Dwelling', '3+ Family Apt.', 'Private Residence', '1-2 FamilyDwelling', '3+ Family Apt', '3+ Family']

# %%
rat_requests['is_residential'] = np.where(rat_requests['location_type'].isin(residential_list)==True, 'is residential', 'not residential')

# %%
rat_requests['is_residential'].value_counts()
# Out:
# is_residential
# is residential     313959
# not residential    117565
# Name: count, dtype: int64

# %%
rat_requests.groupby(['is_residential'])['count_row'].sum().reset_index()
# Out:
#     is_residential  count_row
# 0   is residential     313959
# 1  not residential     117565

# %%
rat_request_res = rat_requests[rat_requests['is_residential'] == 'is residential']

# %%
rat_request_res.shape
# Out:
# (313959, 45)

# %%
rat_request_res.groupby(['borough', 'created_month'])['count_row'].sum().reset_index()
# Out:
#         borough  created_month  count_row
# 0         BRONX              1       4884
# 1         BRONX              2       4665
# 2         BRONX              3       5376
# 3         BRONX              4       5261
# 4         BRONX              5       5783
# ..          ...            ...        ...
# 61  Unspecified              4          7
# 62  Unspecified              5          1
# 63  Unspecified              7          1
# 64  Unspecified              8          1
# 65  Unspecified             12          1
#
# [66 rows x 3 columns]

# %%
rat_requests['tot_row'] = sum(rat_requests['count_row'])
