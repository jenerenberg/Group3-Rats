# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# # **Data**

# %%
# This will take a while, you're import 2.5 million rows
inspections = pd.read_csv(r'https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$limit=3000000')
# Out:
# <ipython-input-16-80b473d9d36d>:2: DtypeWarning: Columns (18,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   inspections = pd.read_csv(r'https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$limit=3000000')

# %%
# query NYC 311 for complaint types with Rodent in the title
query = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$query=" +  requests.utils.quote("SELECT * WHERE complaint_type = 'Rodent' LIMIT 1000000")

# %%
rat_requests = pd.read_csv(query)
# Out:
# <ipython-input-7-ecf3ac6d841d>:1: DtypeWarning: Columns (17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   rat_requests = pd.read_csv(query)

# %%
rodent_inspections = pd.read_csv('https://data.cityofnewyork.us/resource/p937-wjvj.csv')

# %% [markdown]
# # **Data Descriptions**

# %% [markdown]
# **rat_requests**

# %%
rat_requests.head()
# Out:
#    unique_key             created_date closed_date agency  \
# 0    60865813  2024-04-16T01:18:44.000         NaN  DOHMH
# 1    60875030  2024-04-15T23:44:20.000         NaN  DOHMH
# 2    60879577  2024-04-15T23:18:29.000         NaN  DOHMH
# 3    60877282  2024-04-15T23:01:40.000         NaN  DOHMH
# 4    60877275  2024-04-15T22:08:30.000         NaN  DOHMH
#
#                                agency_name complaint_type  \
# 0  Department of Health and Mental Hygiene         Rodent
# 1  Department of Health and Mental Hygiene         Rodent
# 2  Department of Health and Mental Hygiene         Rodent
# 3  Department of Health and Mental Hygiene         Rodent
# 4  Department of Health and Mental Hygiene         Rodent
#
#                      descriptor            location_type  incident_zip  \
# 0                  Rat Sighting        Construction Site       11377.0
# 1                  Rat Sighting  3+ Family Apt. Building       10128.0
# ...

# %%
rat_requests.tail()
# Out:
#         unique_key             created_date closed_date agency  \
# 431371    15633897  2010-01-01T12:12:04.000         NaN  DOHMH
# 431372    15633896  2010-01-01T12:11:51.000         NaN  DOHMH
# 431373    15633965  2010-01-01T12:11:44.000         NaN  DOHMH
# 431374    15633054  2010-01-01T11:20:45.000         NaN  DOHMH
# 431375    15633803  2010-01-01T08:29:58.000         NaN  DOHMH
#
#                                     agency_name complaint_type  \
# 431371  Department of Health and Mental Hygiene         Rodent
# 431372  Department of Health and Mental Hygiene         Rodent
# 431373  Department of Health and Mental Hygiene         Rodent
# 431374  Department of Health and Mental Hygiene         Rodent
# 431375  Department of Health and Mental Hygiene         Rodent
#
#                           descriptor            location_type  incident_zip  \
# 431371                  Rat Sighting  3+ Family Apt. Building       10458.0
# ...

# %%
rat_requests.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
rat_requests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431376 entries, 0 to 431375
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   unique_key                      431376 non-null  int64
#  1   created_date                    431376 non-null  object
#  2   closed_date                     400325 non-null  object
#  3   agency                          431376 non-null  object
#  4   agency_name                     431376 non-null  object
#  5   complaint_type                  431376 non-null  object
#  6   descriptor                      431376 non-null  object
#  7   location_type                   431358 non-null  object
#  8   incident_zip                    430726 non-null  float64
#  9   incident_address                415718 non-null  object
#  10  street_name                     415717 non-null  object
#  11  cross_street_1                  380762 non-null  object
# ...

# %%
rat_requests.shape
# Out:
# (431376, 41)

# %% [markdown]
# **Inspections**

# %%
inspections.head()
# Out:
#    unique_key             created_date              closed_date agency  \
# 0    60879417  2024-04-16T03:03:15.000                      NaN    DOT
# 1    60872531  2024-04-16T02:05:59.000                      NaN    DOT
# 2    60877099  2024-04-16T02:04:38.000                      NaN    DOT
# 3    60873407  2024-04-16T01:44:30.000  2024-04-16T01:44:30.000    DOT
# 4    60866564  2024-04-16T01:43:27.000  2024-04-16T01:43:27.000    DOT
#
#                     agency_name    complaint_type descriptor location_type  \
# 0  Department of Transportation  Street Condition    Pothole           NaN
# 1  Department of Transportation  Street Condition    Pothole           NaN
# 2  Department of Transportation  Street Condition    Pothole           NaN
# 3  Department of Transportation  Street Condition    Pothole           NaN
# 4  Department of Transportation  Street Condition    Pothole           NaN
#
#    incident_zip           incident_address  ... vehicle_type  \
# ...

# %%
inspections['complaint_type'].value_counts()
# Out:
# complaint_type
# Noise - Residential                       235
# Noise - Street/Sidewalk                   195
# Illegal Parking                           152
# Noise - Commercial                         87
# Blocked Driveway                           68
# Noise - Vehicle                            55
# Noise                                      19
# Rodent                                     16
# Illegal Posting                            16
# Noise - Park                               15
# Street Condition                           13
# Traffic Signal Condition                   12
# Street Light Condition                     11
# Abandoned Vehicle                           8
# Non-Emergency Police Matter                 8
# Homeless Person Assistance                  7
# Dirty Condition                             6
# Consumer Complaint                          5
# Graffiti                                    5
# Damaged Tree                                5
# ...

# %%
inspections.tail()
# Out:
#      unique_key             created_date              closed_date agency  \
# 995    60859064  2024-04-14T22:16:57.000                      NaN   DSNY
# 996    60856409  2024-04-14T22:16:49.000  2024-04-14T22:58:45.000   NYPD
# 997    60860777  2024-04-14T22:16:20.000                      NaN    DPR
# 998    60857030  2024-04-14T22:16:06.000                      NaN   NYPD
# 999    60863282  2024-04-14T22:16:04.000  2024-04-14T22:56:31.000   NYPD
#
#                             agency_name           complaint_type  \
# 995            Department of Sanitation          Illegal Posting
# 996     New York City Police Department          Illegal Parking
# 997  Department of Parks and Recreation  Overgrown Tree/Branches
# 998     New York City Police Department          Illegal Parking
# 999     New York City Police Department      Noise - Residential
#
#                        descriptor               location_type  incident_zip  \
# ...

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      1000 non-null   int64
#  1   created_date                    1000 non-null   object
#  2   closed_date                     547 non-null    object
#  3   agency                          1000 non-null   object
#  4   agency_name                     1000 non-null   object
#  5   complaint_type                  1000 non-null   object
#  6   descriptor                      996 non-null    object
#  7   location_type                   949 non-null    object
#  8   incident_zip                    997 non-null    float64
#  9   incident_address                974 non-null    object
#  10  street_name                     974 non-null    object
#  11  cross_street_1                  967 non-null    object
# ...

# %%
inspections.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
inspections.shape
# Out:
# (1000, 41)

# %%
inspections['closed_date'] = .value_counts()
# Out:
# closed_date
# 2024-04-15T00:24:13.000    3
# 2024-04-15T01:19:48.000    2
# 2024-04-15T01:19:11.000    2
# 2024-04-15T01:10:56.000    2
# 2024-04-15T00:18:10.000    2
#                           ..
# 2024-04-15T00:51:55.000    1
# 2024-04-15T00:49:54.000    1
# 2024-04-15T00:13:39.000    1
# 2024-04-15T00:34:42.000    1
# 2024-04-14T22:56:31.000    1
# Name: count, Length: 520, dtype: int64

# %% [markdown]
# **rodent_inspections**

# %%
rodent_inspections.head()
# Out:
#   inspection_type  job_ticket_or_work_order_id     job_id  job_progress  \
# 0         Initial                     13661515  PC8122655             1
# 1         Initial                     11507405  PC7504205             1
# 2         Initial                     13264492  PC7744572             1
# 3         Initial                     13252138  PC7732344             1
# 4      Compliance                     13039020  PC6844689             2
#
#             bbl  boro_code  block  lot house_number      street_name  ...  \
# 0           NaN          1    529    9          NaN              NaN  ...
# 1           NaN          5     62  113          000      YORK AVENUE  ...
# 2           NaN          2   2857   95         0000    JEROME AVENUE  ...
# 3           NaN          2   2409   59          NaN              NaN  ...
# 4  2.039130e+09          2   3913   42         1529  ROSEDALE AVENUE  ...
#
#          borough          inspection_date              result  \
# ...

# %%
rodent_inspections['closed']

# %%
rodent_inspections.tail()
# Out:
#     inspection_type  job_ticket_or_work_order_id     job_id  job_progress  \
# 995            BAIT                      2424263  PC7339283            16
# 996         Initial                     12211829  PC6278118             1
# 997         Initial                     11605947  PC6962651             1
# 998         Initial                     13458631  PC7930996             1
# 999         Initial                     13566700  PC8009271             1
#
#      bbl  boro_code  block  lot house_number      street_name  ...    borough  \
# 995  NaN          4   9905  101          000        184 PLACE  ...     Queens
# 996  NaN          1    544   57          NaN              NaN  ...  Manhattan
# 997  NaN          2   2420  172          NaN       PARK PLACE  ...      Bronx
# 998  NaN          2   3211    1         0000  AQUEDUCT AVENUE  ...      Bronx
# 999  NaN          2   4098   11     PAULDING           AVENUE  ...      Bronx
#
# ...

# %%
rodent_inspections.columns
# Out:
# Index(['inspection_type', 'job_ticket_or_work_order_id', 'job_id',
#        'job_progress', 'bbl', 'boro_code', 'block', 'lot', 'house_number',
#        'street_name', 'zip_code', 'x_coord', 'y_coord', 'latitude',
#        'longitude', 'borough', 'inspection_date', 'result', 'approved_date',
#        'location', 'community_board', 'council_district', 'census_tract',
#        'bin', 'nta'],
#       dtype='object')

# %%
rodent_inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   inspection_type              1000 non-null   object
#  1   job_ticket_or_work_order_id  1000 non-null   int64
#  2   job_id                       1000 non-null   object
#  3   job_progress                 1000 non-null   int64
#  4   bbl                          33 non-null     float64
#  5   boro_code                    1000 non-null   int64
#  6   block                        1000 non-null   int64
#  7   lot                          1000 non-null   int64
#  8   house_number                 555 non-null    object
#  9   street_name                  800 non-null    object
#  10  zip_code                     651 non-null    float64
#  11  x_coord                      375 non-null    float64
#  12  y_coord                      375 non-null    float64
# ...

# %%
rodent_inspections.shape
# Out:
# (1000, 25)

# %%
inspections.shape
# Out:
# (3000000, 41)

# %% [markdown]
# #Grouping Rodent Inspections by Borough

# %%
rodent_inspections['count_row'] = 1

# %%
rat_requests['count_row'] = 1

# %%
inspection_year_borough = rodent_inspections.groupby(['inspection_year','borough'])['count_row'].sum().reset_index()

# %%
inspection_year_borough.head()
# Out:
#    inspection_year   borough  count_row
# 0             2009     Bronx          1
# 1             2009  Brooklyn          2
# 2             2009    Queens          1
# 3             2010     Bronx         13
# 4             2010  Brooklyn          5

# %%
rat_requests.groupby(['borough'])['count_row'].sum()
# Out:
# borough
# BRONX             81911
# BROOKLYN         150488
# MANHATTAN        104361
# QUEENS            74214
# STATEN ISLAND     20368
# Unspecified          27
# Name: count_row, dtype: int64

# %% [markdown]
# #Converting Columns

# %%
rodent_inspections['inspection_date'] = pd.to_datetime(rodent_inspections['inspection_date'])

# %%
rodent_inspections['inspection_year'] = rodent_inspections['inspection_date'].dt.year

# %%
rodent_inspections['inspection_year'].value_counts()
# Out:
# inspection_year
# 2022    114
# 2018    109
# 2019    100
# 2017     91
# 2012     91
# 2016     77
# 2011     69
# 2015     64
# 2010     62
# 2013     56
# 2023     53
# 2014     47
# 2021     33
# 2020     30
# 2009      4
# Name: count, dtype: int64

# %%
rodent_inspections['inspection_date']
# Out:
# 0     2015-08-04 15:38:42
# 1     2010-04-29 14:41:02
# 2     2013-06-03 12:05:47
# 3     2019-05-28 15:50:27
# 4     2016-10-03 14:57:54
#               ...
# 995   2022-02-23 12:46:42
# 996   2015-11-30 10:28:53
# 997   2019-10-11 16:12:27
# 998   2023-04-27 12:15:06
# 999   2020-02-28 10:30:09
# Name: inspection_date, Length: 1000, dtype: datetime64[ns]

# %%
inspections['created_date'] = pd.to_datetime(inspections['created_date'])

# %%
inspections['closed_date'] = pd.to_datetime(inspections['closed_date'])

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      1000 non-null   int64
#  1   created_date                    1000 non-null   datetime64[ns]
#  2   closed_date                     547 non-null    datetime64[ns]
#  3   agency                          1000 non-null   object
#  4   agency_name                     1000 non-null   object
#  5   complaint_type                  1000 non-null   object
#  6   descriptor                      996 non-null    object
#  7   location_type                   949 non-null    object
#  8   incident_zip                    997 non-null    float64
#  9   incident_address                974 non-null    object
#  10  street_name                     974 non-null    object
#  11  cross_street_1                  967 non-null    object
# ...

# %%
inspections['due_date']
# Out:
# 0      2024-05-15T01:45:56.000
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#                 ...
# 995                        NaN
# 996                        NaN
# 997                        NaN
# 998                        NaN
# 999                        NaN
# Name: due_date, Length: 1000, dtype: object

# %%
rat_requests['created_date'] = pd.to_datetime(rat_requests['created_date'])

# %%
rat_requests['closed_date'] = pd.to_datetime(rat_requests['closed_date'])

# %%
rat_requests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431376 entries, 0 to 431375
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   unique_key                      431376 non-null  int64
#  1   created_date                    431376 non-null  datetime64[ns]
#  2   closed_date                     400325 non-null  datetime64[ns]
#  3   agency                          431376 non-null  object
#  4   agency_name                     431376 non-null  object
#  5   complaint_type                  431376 non-null  object
#  6   descriptor                      431376 non-null  object
#  7   location_type                   431358 non-null  object
#  8   incident_zip                    430726 non-null  float64
#  9   incident_address                415718 non-null  object
#  10  street_name                     415717 non-null  object
# ...
