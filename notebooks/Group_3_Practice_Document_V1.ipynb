# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd

# %% [markdown]
# # **Data**

# %%
# This will take a while, you're import 2.5 million rows
inspections = pd.read_csv(r'https://data.cityofnewyork.us/resource/erm2-nwe9.csv')

# %%
# query NYC 311 for complaint types with Rodent in the title
query = "https://data.cityofnewyork.us/resource/erm2-nwe9.csv?$query=" +  requests.utils.quote("SELECT * WHERE complaint_type = 'Rodent' LIMIT 1000000")

# %%
rat_requests = pd.read_csv(query)
# Out:
# <ipython-input-6-ecf3ac6d841d>:1: DtypeWarning: Columns (17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   rat_requests = pd.read_csv(query)

# %%
rodent_inspections = pd.read_csv('https://data.cityofnewyork.us/resource/p937-wjvj.csv')

# %% [markdown]
# # **Data Descriptions**

# %% [markdown]
# **rat_requests**

# %%
rat_requests.head()
# Out:
#    unique_key             created_date closed_date agency  \
# 0    60821414  2024-04-10T00:17:13.000         NaN  DOHMH
# 1    60816204  2024-04-10T00:14:39.000         NaN  DOHMH
# 2    60822700  2024-04-10T00:07:13.000         NaN  DOHMH
# 3    60824082  2024-04-09T23:54:02.000         NaN  DOHMH
# 4    60824089  2024-04-09T23:41:39.000         NaN  DOHMH
#
#                                agency_name complaint_type        descriptor  \
# 0  Department of Health and Mental Hygiene         Rodent      Rat Sighting
# 1  Department of Health and Mental Hygiene         Rodent      Rat Sighting
# 2  Department of Health and Mental Hygiene         Rodent      Rat Sighting
# 3  Department of Health and Mental Hygiene         Rodent    Mouse Sighting
# 4  Department of Health and Mental Hygiene         Rodent  Signs of Rodents
#
#              location_type  incident_zip      incident_address  ...  \
# 0  3+ Family Apt. Building       10452.0  1450 TOWNSEND AVENUE  ...
# 1  3+ Family Apt. Building       10452.0  1466 TOWNSEND AVENUE  ...
# 2  3+ Family Apt. Building       10452.0   50 EAST  172 STREET  ...
# 3  3+ Family Apt. Building       10034.0      97 SEAMAN AVENUE  ...
# 4  3+ Family Apt. Building       11208.0   375 FOUNTAIN AVENUE  ...
#
#   vehicle_type taxi_company_borough taxi_pick_up_location bridge_highway_name  \
# 0          NaN                  NaN                   NaN                 NaN
# 1          NaN                  NaN                   NaN                 NaN
# 2          NaN                  NaN                   NaN                 NaN
# 3          NaN                  NaN                   NaN                 NaN
# 4          NaN                  NaN                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 0                      NaN       NaN                    NaN  40.841119
# 1                      NaN       NaN                    NaN  40.841350
# 2                      NaN       NaN                    NaN  40.841904
# 3                      NaN       NaN                    NaN  40.868268
# 4                      NaN       NaN                    NaN  40.670229
#
#    longitude                                         location
# 0 -73.915893   \n,  \n(40.84111937693655, -73.91589259915179)
# 1 -73.915726  \n,  \n(40.841349810978734, -73.91572605845745)
# 2 -73.915176  \n,  \n(40.841903839077396, -73.91517600632936)
# 3 -73.924554  \n,  \n(40.868267734000455, -73.92455372965492)
# 4 -73.874061   \n,  \n(40.67022900572846, -73.87406118798549)
#
# [5 rows x 41 columns]

# %%
rat_requests.tail()
# Out:
#         unique_key             created_date closed_date agency  \
# 430691    15633897  2010-01-01T12:12:04.000         NaN  DOHMH
# 430692    15633896  2010-01-01T12:11:51.000         NaN  DOHMH
# 430693    15633965  2010-01-01T12:11:44.000         NaN  DOHMH
# 430694    15633054  2010-01-01T11:20:45.000         NaN  DOHMH
# 430695    15633803  2010-01-01T08:29:58.000         NaN  DOHMH
#
#                                     agency_name complaint_type  \
# 430691  Department of Health and Mental Hygiene         Rodent
# 430692  Department of Health and Mental Hygiene         Rodent
# 430693  Department of Health and Mental Hygiene         Rodent
# 430694  Department of Health and Mental Hygiene         Rodent
# 430695  Department of Health and Mental Hygiene         Rodent
#
#                           descriptor            location_type  incident_zip  \
# 430691                  Rat Sighting  3+ Family Apt. Building       10458.0
# 430692                  Rat Sighting  3+ Family Apt. Building       10027.0
# 430693  Condition Attracting Rodents      1-2 Family Dwelling       11420.0
# 430694                  Rat Sighting      1-2 Family Dwelling       11365.0
# 430695                  Rat Sighting  3+ Family Apt. Building       11206.0
#
#             incident_address  ... vehicle_type taxi_company_borough  \
# 430691  2356 LORILLARD PLACE  ...          NaN                  NaN
# 430692   317 WEST 120 STREET  ...          NaN                  NaN
# 430693     119-27 130 STREET  ...          NaN                  NaN
# 430694      59-13 159 STREET  ...          NaN                  NaN
# 430695    202 PULASKI STREET  ...          NaN                  NaN
#
#        taxi_pick_up_location bridge_highway_name bridge_highway_direction  \
# 430691                   NaN                 NaN                      NaN
# 430692                   NaN                 NaN                      NaN
# 430693                   NaN                 NaN                      NaN
# 430694                   NaN                 NaN                      NaN
# 430695                   NaN                 NaN                      NaN
#
#        road_ramp bridge_highway_segment   latitude  longitude  \
# 430691       NaN                    NaN  40.855513 -73.890006
# 430692       NaN                    NaN  40.807367 -73.954388
# 430693       NaN                    NaN  40.674091 -73.808377
# 430694       NaN                    NaN  40.739983 -73.809299
# 430695       NaN                    NaN  40.692989 -73.943771
#
#                                                location
# 430691   \n,  \n(40.85551279775197, -73.89000626904053)
# 430692  \n,  \n(40.807367287308594, -73.95438787024435)
# 430693   \n,  \n(40.67409083763361, -73.80837696748092)
# 430694   \n,  \n(40.73998332248969, -73.80929891501533)
# 430695   \n,  \n(40.69298896011082, -73.94377050323628)
#
# [5 rows x 41 columns]

# %%
rat_requests.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
rat_requests.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430696 entries, 0 to 430695
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   unique_key                      430696 non-null  int64
#  1   created_date                    430696 non-null  object
#  2   closed_date                     399894 non-null  object
#  3   agency                          430696 non-null  object
#  4   agency_name                     430696 non-null  object
#  5   complaint_type                  430696 non-null  object
#  6   descriptor                      430696 non-null  object
#  7   location_type                   430678 non-null  object
#  8   incident_zip                    430045 non-null  float64
#  9   incident_address                415038 non-null  object
#  10  street_name                     415037 non-null  object
#  11  cross_street_1                  380082 non-null  object
#  12  cross_street_2                  380111 non-null  object
#  13  intersection_street_1           195940 non-null  object
#  14  intersection_street_2           196010 non-null  object
#  15  address_type                    429931 non-null  object
#  16  city                            425842 non-null  object
#  17  landmark                        165976 non-null  object
#  18  facility_type                   0 non-null       float64
#  19  status                          430696 non-null  object
#  20  due_date                        255961 non-null  object
#  21  resolution_description          405683 non-null  object
#  22  resolution_action_updated_date  416604 non-null  object
#  23  community_board                 430689 non-null  object
#  24  bbl                             360216 non-null  float64
#  25  borough                         430689 non-null  object
#  26  x_coordinate_state_plane        427680 non-null  float64
#  27  y_coordinate_state_plane        427685 non-null  float64
#  28  open_data_channel_type          430696 non-null  object
#  29  park_facility_name              430696 non-null  object
#  30  park_borough                    430689 non-null  object
#  31  vehicle_type                    0 non-null       float64
#  32  taxi_company_borough            0 non-null       float64
#  33  taxi_pick_up_location           0 non-null       float64
#  34  bridge_highway_name             0 non-null       float64
#  35  bridge_highway_direction        0 non-null       float64
#  36  road_ramp                       0 non-null       float64
#  37  bridge_highway_segment          0 non-null       float64
#  38  latitude                        427680 non-null  float64
#  39  longitude                       427680 non-null  float64
#  40  location                        427680 non-null  object
# dtypes: float64(14), int64(1), object(26)
# memory usage: 134.7+ MB

# %%
rat_requests.shape
# Out:
# (430696, 41)

# %% [markdown]
# Inspections

# %%
inspections.head()
# Out:
#    unique_key             created_date              closed_date agency  \
# 0    60824270  2024-04-10T12:00:00.000  2024-04-10T12:00:00.000   DSNY
# 1    60814762  2024-04-10T02:50:06.000                      NaN    DOT
# 2    60821292  2024-04-10T02:30:23.000                      NaN    DOT
# 3    60822800  2024-04-10T01:50:51.000                      NaN   NYPD
# 4    60824190  2024-04-10T01:50:45.000                      NaN   NYPD
#
#                        agency_name       complaint_type         descriptor  \
# 0         Department of Sanitation    Derelict Vehicles  Derelict Vehicles
# 1     Department of Transportation     Street Condition            Pothole
# 2     Department of Transportation     Street Condition            Pothole
# 3  New York City Police Department  Noise - Residential   Loud Music/Party
# 4  New York City Police Department  Noise - Residential   Loud Music/Party
#
#                 location_type  incident_zip          incident_address  ...  \
# 0                      Street       11229.0  2803 GRAVESEND NECK ROAD  ...
# 1                         NaN       11428.0                       NaN  ...
# 2                         NaN       11377.0                       NaN  ...
# 3  Residential Building/House       10458.0           458 CYRUS PLACE  ...
# 4  Residential Building/House       10473.0     635 CASTLEHILL AVENUE  ...
#
#   vehicle_type taxi_company_borough taxi_pick_up_location bridge_highway_name  \
# 0          NaN                  NaN                   NaN                 NaN
# 1          NaN                  NaN                   NaN                 NaN
# 2          NaN                  NaN                   NaN                 NaN
# 3          NaN                  NaN                   NaN                 NaN
# 4          NaN                  NaN                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment   latitude  \
# 0                      NaN       NaN                    NaN  40.599512
# 1                      NaN       NaN                    NaN  40.715144
# 2                      NaN       NaN                    NaN  40.742685
# 3                      NaN       NaN                    NaN  40.858476
# 4                      NaN       NaN                    NaN  40.820103
#
#    longitude                                         location
# 0 -73.943529   \n,  \n(40.59951246697324, -73.94352873366437)
# 1 -73.749356   \n,  \n(40.71514359811922, -73.74935561892977)
# 2 -73.895653  \n,  \n(40.742684984899114, -73.89565260528727)
# 3 -73.891361   \n,  \n(40.85847561546126, -73.89136062711695)
# 4 -73.848292    \n,  \n(40.82010259053273, -73.8482916979425)
#
# [5 rows x 41 columns]

# %%
inspections.tail()
# Out:
#      unique_key             created_date              closed_date agency  \
# 995    60814474  2024-04-09T22:39:13.000  2024-04-10T00:39:15.000   NYPD
# 996    60815833  2024-04-09T22:38:51.000  2024-04-09T22:52:26.000   NYPD
# 997    60820657  2024-04-09T22:38:38.000  2024-04-10T01:32:32.000   NYPD
# 998    60818953  2024-04-09T22:38:33.000                      NaN    EDC
# 999    60818702  2024-04-09T22:38:07.000                      NaN    HPD
#
#                                            agency_name  \
# 995                    New York City Police Department
# 996                    New York City Police Department
# 997                    New York City Police Department
# 998                   Economic Development Corporation
# 999  Department of Housing Preservation and Develop...
#
#               complaint_type                    descriptor  \
# 995  Noise - Street/Sidewalk              Loud Music/Party
# 996  Noise - Street/Sidewalk              Loud Music/Party
# 997          Illegal Parking  Commercial Overnight Parking
# 998       Noise - Helicopter                         Other
# 999               WATER LEAK                    HEAVY FLOW
#
#             location_type  incident_zip       incident_address  ...  \
# 995       Street/Sidewalk       10456.0    1226 SHERMAN AVENUE  ...
# 996       Street/Sidewalk       10453.0     2240 JEROME AVENUE  ...
# 997       Street/Sidewalk       11235.0  2402 EAST   26 STREET  ...
# 998         Above Address       10023.0    37 WEST   73 STREET  ...
# 999  RESIDENTIAL BUILDING       10457.0    1899 BELMONT AVENUE  ...
#
#     vehicle_type taxi_company_borough taxi_pick_up_location  \
# 995          NaN                  NaN                   NaN
# 996          NaN                  NaN                   NaN
# 997          NaN                  NaN                   NaN
# 998          NaN                  NaN                   NaN
# 999          NaN                  NaN                   NaN
#
#     bridge_highway_name bridge_highway_direction road_ramp  \
# 995                 NaN                      NaN       NaN
# 996                 NaN                      NaN       NaN
# 997                 NaN                      NaN       NaN
# 998                 NaN                      NaN       NaN
# 999                 NaN                      NaN       NaN
#
#     bridge_highway_segment   latitude  longitude  \
# 995                    NaN  40.834562 -73.915424
# 996                    NaN  40.857603 -73.904344
# 997                    NaN  40.593038 -73.944355
# 998                    NaN  40.777657 -73.977231
# 999                    NaN  40.844866 -73.892839
#
#                                            location
# 995  \n,  \n(40.83456191927017, -73.91542387418657)
# 996  \n,  \n(40.85760331599933, -73.90434351867661)
# 997  \n,  \n(40.59303788943512, -73.94435516323492)
# 998  \n,  \n(40.77765686769006, -73.97723119132257)
# 999   \n,  \n(40.8448660045057, -73.89283942002938)
#
# [5 rows x 41 columns]

# %%
inspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 41 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   unique_key                      1000 non-null   int64
#  1   created_date                    1000 non-null   object
#  2   closed_date                     546 non-null    object
#  3   agency                          1000 non-null   object
#  4   agency_name                     1000 non-null   object
#  5   complaint_type                  1000 non-null   object
#  6   descriptor                      929 non-null    object
#  7   location_type                   952 non-null    object
#  8   incident_zip                    997 non-null    float64
#  9   incident_address                981 non-null    object
#  10  street_name                     981 non-null    object
#  11  cross_street_1                  937 non-null    object
#  12  cross_street_2                  937 non-null    object
#  13  intersection_street_1           922 non-null    object
#  14  intersection_street_2           922 non-null    object
#  15  address_type                    998 non-null    object
#  16  city                            920 non-null    object
#  17  landmark                        828 non-null    object
#  18  facility_type                   0 non-null      float64
#  19  status                          1000 non-null   object
#  20  due_date                        2 non-null      object
#  21  resolution_description          607 non-null    object
#  22  resolution_action_updated_date  746 non-null    object
#  23  community_board                 1000 non-null   object
#  24  bbl                             863 non-null    float64
#  25  borough                         1000 non-null   object
#  26  x_coordinate_state_plane        979 non-null    float64
#  27  y_coordinate_state_plane        979 non-null    float64
#  28  open_data_channel_type          1000 non-null   object
#  29  park_facility_name              1000 non-null   object
#  30  park_borough                    1000 non-null   object
#  31  vehicle_type                    89 non-null     object
#  32  taxi_company_borough            0 non-null      float64
#  33  taxi_pick_up_location           10 non-null     object
#  34  bridge_highway_name             2 non-null      object
#  35  bridge_highway_direction        1 non-null      object
#  36  road_ramp                       1 non-null      object
#  37  bridge_highway_segment          2 non-null      object
#  38  latitude                        979 non-null    float64
#  39  longitude                       979 non-null    float64
#  40  location                        979 non-null    object
# dtypes: float64(8), int64(1), object(32)
# memory usage: 320.4+ KB

# %%
inspections.columns
# Out:
# Index(['unique_key', 'created_date', 'closed_date', 'agency', 'agency_name',
#        'complaint_type', 'descriptor', 'location_type', 'incident_zip',
#        'incident_address', 'street_name', 'cross_street_1', 'cross_street_2',
#        'intersection_street_1', 'intersection_street_2', 'address_type',
#        'city', 'landmark', 'facility_type', 'status', 'due_date',
#        'resolution_description', 'resolution_action_updated_date',
#        'community_board', 'bbl', 'borough', 'x_coordinate_state_plane',
#        'y_coordinate_state_plane', 'open_data_channel_type',
#        'park_facility_name', 'park_borough', 'vehicle_type',
#        'taxi_company_borough', 'taxi_pick_up_location', 'bridge_highway_name',
#        'bridge_highway_direction', 'road_ramp', 'bridge_highway_segment',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %%
inspections.shape
# Out:
# (1000, 41)
